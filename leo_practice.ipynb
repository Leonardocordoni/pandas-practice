# %%
import pandas as pd

# %%
bios = pd.read_csv("./data/bios.csv")

# %%
bios.loc[bios["height_cm"] == 135]
# Out:
#         athlete_id            name   born_date born_city      born_region  \
# 4505          4520     Peter Ayesu  1962-06-01       NaN              NaN
# 28762        28976  Choi Myong-Hui  1966-06-13       NaN              NaN
# 101552      102450   Jana Labáková  1966-01-26     Detva  Banská Bystrica
#
#        born_country                                    NOC  height_cm  \
# 4505            NaN                                 Malawi      135.0
# 28762           NaN  Democratic People's Republic of Korea      135.0
# 101552          SVK                         Czechoslovakia      135.0
#
#         weight_kg died_date
# 4505         51.0       NaN
# 28762        25.0       NaN
# 101552       34.0       NaN
